# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
data = pd.read_csv('data/DS_Jobs.csv')

# %%
data.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
#                       Size        Type of ownership  \
# 0   1001 to 5000 employees   Nonprofit Organization
# 1  5001 to 10000 employees         Company - Public
# 2   1001 to 5000 employees  Private Practice / Firm
# 3    501 to 1000 employees         Company - Public
# 4      51 to 200 employees        Company - Private
#
#                                 Industry  ... company_age python  excel  \
# 0                     Insurance Carriers  ...          27      0      0
# 1                 Research & Development  ...          52      0      0
# 2                             Consulting  ...          39      1      1
# 3  Electrical & Electronic Manufacturing  ...          20      1      1
# 4                Advertising & Marketing  ...          22      1      1
#
#    hadoop  spark aws  tableau  big_data        job_simp  seniority
# 0       0      0   1        0         0  data scientist     senior
# 1       1      0   0        0         1  data scientist         na
# 2       0      0   1        0         0  data scientist         na
# 3       0      0   1        0         0  data scientist         na
# 4       0      0   0        0         0  data scientist         na
#
# [5 rows x 27 columns]

# %%
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'min_salary', 'max_salary',
#        'avg_salary', 'job_state', 'same_state', 'company_age', 'python',
#        'excel', 'hadoop', 'spark', 'aws', 'tableau', 'big_data', 'job_simp',
#        'seniority'],
#       dtype='object')

# %%
# keep necessary columns
df = data[['Job Title', 'Company Name', 'Location', 'Size', 'Industry', 'avg_salary', 'job_state', 'python', 'excel',
          'hadoop', 'spark', 'aws', 'tableau', 'big_data']]
df
# Out:
#              Job Title          Company Name           Location  \
# 0    Sr Data Scientist           Healthfirst       New York, NY
# 1       Data Scientist               ManTech      Chantilly, VA
# 2       Data Scientist        Analysis Group         Boston, MA
# 3       Data Scientist               INFICON         Newton, MA
# 4       Data Scientist    Affinity Solutions       New York, NY
# ..                 ...                   ...                ...
# 655     Data Scientist              TRANZACT       Fort Lee, NJ
# 656     Data Scientist                  JKGT  San Francisco, CA
# 657     Data Scientist            AccessHope      Irwindale, CA
# 658     Data Scientist  ChaTeck Incorporated  San Francisco, CA
# 659     Data Scientist         1-800-Flowers       New York, NY
#
#                         Size                               Industry  \
# 0     1001 to 5000 employees                     Insurance Carriers
# 1    5001 to 10000 employees                 Research & Development
# 2     1001 to 5000 employees                             Consulting
# 3      501 to 1000 employees  Electrical & Electronic Manufacturing
# 4        51 to 200 employees                Advertising & Marketing
# ..                       ...                                    ...
# 655   1001 to 5000 employees                Advertising & Marketing
# 656                       -1                                     -1
# 657                       -1                                     -1
# 658        1 to 50 employees                Advertising & Marketing
# 659   1001 to 5000 employees                              Wholesale
#
#      avg_salary job_state  python  excel  hadoop  spark  aws  tableau  \
# 0           154        NY       0      0       0      0    1        0
# 1           154        VA       0      0       1      0    0        0
# 2           154        MA       1      1       0      0    1        0
# 3           154        MA       1      1       0      0    1        0
# 4           154        NY       1      1       0      0    0        0
# ..          ...       ...     ...    ...     ...    ...  ...      ...
# 655         136        NJ       1      1       1      0    0        1
# 656         136        CA       0      0       0      0    0        0
# 657         136        CA       1      1       1      0    0        1
# 658         136        CA       1      0       1      1    0        0
# 659         136        NY       1      1       0      0    0        1
#
#      big_data
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
# ..        ...
# 655         1
# 656         0
# 657         0
# 658         1
# 659         0
#
# [660 rows x 14 columns]

# %%
# replace -1 values with NaN using np
df1 = df.replace('-1', np.nan)
df1
# Out:
#              Job Title          Company Name           Location  \
# 0    Sr Data Scientist           Healthfirst       New York, NY
# 1       Data Scientist               ManTech      Chantilly, VA
# 2       Data Scientist        Analysis Group         Boston, MA
# 3       Data Scientist               INFICON         Newton, MA
# 4       Data Scientist    Affinity Solutions       New York, NY
# ..                 ...                   ...                ...
# 655     Data Scientist              TRANZACT       Fort Lee, NJ
# 656     Data Scientist                  JKGT  San Francisco, CA
# 657     Data Scientist            AccessHope      Irwindale, CA
# 658     Data Scientist  ChaTeck Incorporated  San Francisco, CA
# 659     Data Scientist         1-800-Flowers       New York, NY
#
#                         Size                               Industry  \
# 0     1001 to 5000 employees                     Insurance Carriers
# 1    5001 to 10000 employees                 Research & Development
# 2     1001 to 5000 employees                             Consulting
# 3      501 to 1000 employees  Electrical & Electronic Manufacturing
# 4        51 to 200 employees                Advertising & Marketing
# ..                       ...                                    ...
# 655   1001 to 5000 employees                Advertising & Marketing
# 656                      NaN                                    NaN
# 657                      NaN                                    NaN
# 658        1 to 50 employees                Advertising & Marketing
# 659   1001 to 5000 employees                              Wholesale
#
#      avg_salary job_state  python  excel  hadoop  spark  aws  tableau  \
# 0           154        NY       0      0       0      0    1        0
# 1           154        VA       0      0       1      0    0        0
# 2           154        MA       1      1       0      0    1        0
# 3           154        MA       1      1       0      0    1        0
# 4           154        NY       1      1       0      0    0        0
# ..          ...       ...     ...    ...     ...    ...  ...      ...
# 655         136        NJ       1      1       1      0    0        1
# 656         136        CA       0      0       0      0    0        0
# 657         136        CA       1      1       1      0    0        1
# 658         136        CA       1      0       1      1    0        0
# 659         136        NY       1      1       0      0    0        1
#
#      big_data
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
# ..        ...
# 655         1
# 656         0
# 657         0
# 658         1
# 659         0
#
# [660 rows x 14 columns]

# %%
# drop all NaN values
df1 = df1.dropna(axis=0, how='any')
df1
# Out:
#              Job Title             Company Name           Location  \
# 0    Sr Data Scientist              Healthfirst       New York, NY
# 1       Data Scientist                  ManTech      Chantilly, VA
# 2       Data Scientist           Analysis Group         Boston, MA
# 3       Data Scientist                  INFICON         Newton, MA
# 4       Data Scientist       Affinity Solutions       New York, NY
# ..                 ...                      ...                ...
# 653     Data Scientist  Criterion Systems, Inc.         Vienna, VA
# 654     Data Scientist      Foundation Medicine         Boston, MA
# 655     Data Scientist                 TRANZACT       Fort Lee, NJ
# 658     Data Scientist     ChaTeck Incorporated  San Francisco, CA
# 659     Data Scientist            1-800-Flowers       New York, NY
#
#                         Size                               Industry  \
# 0     1001 to 5000 employees                     Insurance Carriers
# 1    5001 to 10000 employees                 Research & Development
# 2     1001 to 5000 employees                             Consulting
# 3      501 to 1000 employees  Electrical & Electronic Manufacturing
# 4        51 to 200 employees                Advertising & Marketing
# ..                       ...                                    ...
# 653     201 to 500 employees                            IT Services
# 654   1001 to 5000 employees              Biotech & Pharmaceuticals
# 655   1001 to 5000 employees                Advertising & Marketing
# 658        1 to 50 employees                Advertising & Marketing
# 659   1001 to 5000 employees                              Wholesale
#
#      avg_salary job_state  python  excel  hadoop  spark  aws  tableau  \
# 0           154        NY       0      0       0      0    1        0
# 1           154        VA       0      0       1      0    0        0
# 2           154        MA       1      1       0      0    1        0
# 3           154        MA       1      1       0      0    1        0
# 4           154        NY       1      1       0      0    0        0
# ..          ...       ...     ...    ...     ...    ...  ...      ...
# 653         136        VA       1      1       0      0    0        0
# 654         136        MA       1      0       0      0    0        0
# 655         136        NJ       1      1       1      0    0        1
# 658         136        CA       1      0       1      1    0        0
# 659         136        NY       1      1       0      0    0        1
#
#      big_data
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
# ..        ...
# 653         0
# 654         0
# 655         1
# 658         1
# 659         0
#
# [589 rows x 14 columns]

# %%
# spot check Delaware. Will drop this later on because it is an outlier for avg salary
df1[df1.job_state == ' DE']
# Out:
#                               Job Title Company Name        Location  \
# 500  Real World Science, Data Scientist  AstraZeneca  Wilmington, DE
#
#                  Size                   Industry  avg_salary job_state  \
# 500  10000+ employees  Biotech & Pharmaceuticals         271        DE
#
#      python  excel  hadoop  spark  aws  tableau  big_data
# 500       1      0       1      0    0        0         0

# %%
# drop all locations not specified with city, that only list United States
df2 = df1[df1['Location'] != 'United States']
df2
# Out:
#              Job Title             Company Name           Location  \
# 0    Sr Data Scientist              Healthfirst       New York, NY
# 1       Data Scientist                  ManTech      Chantilly, VA
# 2       Data Scientist           Analysis Group         Boston, MA
# 3       Data Scientist                  INFICON         Newton, MA
# 4       Data Scientist       Affinity Solutions       New York, NY
# ..                 ...                      ...                ...
# 653     Data Scientist  Criterion Systems, Inc.         Vienna, VA
# 654     Data Scientist      Foundation Medicine         Boston, MA
# 655     Data Scientist                 TRANZACT       Fort Lee, NJ
# 658     Data Scientist     ChaTeck Incorporated  San Francisco, CA
# 659     Data Scientist            1-800-Flowers       New York, NY
#
#                         Size                               Industry  \
# 0     1001 to 5000 employees                     Insurance Carriers
# 1    5001 to 10000 employees                 Research & Development
# 2     1001 to 5000 employees                             Consulting
# 3      501 to 1000 employees  Electrical & Electronic Manufacturing
# 4        51 to 200 employees                Advertising & Marketing
# ..                       ...                                    ...
# 653     201 to 500 employees                            IT Services
# 654   1001 to 5000 employees              Biotech & Pharmaceuticals
# 655   1001 to 5000 employees                Advertising & Marketing
# 658        1 to 50 employees                Advertising & Marketing
# 659   1001 to 5000 employees                              Wholesale
#
#      avg_salary job_state  python  excel  hadoop  spark  aws  tableau  \
# 0           154        NY       0      0       0      0    1        0
# 1           154        VA       0      0       1      0    0        0
# 2           154        MA       1      1       0      0    1        0
# 3           154        MA       1      1       0      0    1        0
# 4           154        NY       1      1       0      0    0        0
# ..          ...       ...     ...    ...     ...    ...  ...      ...
# 653         136        VA       1      1       0      0    0        0
# 654         136        MA       1      0       0      0    0        0
# 655         136        NJ       1      1       1      0    0        1
# 658         136        CA       1      0       1      1    0        0
# 659         136        NY       1      1       0      0    0        1
#
#      big_data
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
# ..        ...
# 653         0
# 654         0
# 655         1
# 658         1
# 659         0
#
# [579 rows x 14 columns]

# %%
# locations with the most data scientist job postings
location = df2.Location.value_counts()
location[:30]
# Out:
# New York, NY               46
# San Francisco, CA          45
# Boston, MA                 24
# Washington, DC             22
# Herndon, VA                21
# Chicago, IL                21
# Cambridge, MA              16
# McLean, VA                 11
# Chantilly, VA               9
# Saint Louis, MO             8
# Atlanta, GA                 7
# Gaithersburg, MD            7
# Redwood City, CA            7
# San Diego, CA               7
# Santa Clara, CA             7
# Reston, VA                  7
# Baltimore, MD               5
# Denver, CO                  5
# Falls Church, VA            5
# Annapolis Junction, MD      5
# Seattle, WA                 5
# South San Francisco, CA     4
# Palo Alto, CA               4
# San Jose, CA                4
# Bethesda, MD                4
# Thousand Oaks, CA           4
# Oklahoma City, OK           4
# Plano, TX                   4
# Fort Belvoir, VA            4
# Alexandria, VA              4
# Name: Location, dtype: int64

# %%
# Count of positions posted in top industries
industry = pd.DataFrame(df2.Industry.value_counts())
#industry = industry[['Industry', 'Postings']]
inds = industry.reset_index()
inds.columns=['Industry', 'Postings']
inds[:15]
# Out:
#                                    Industry  Postings
# 0                 Biotech & Pharmaceuticals        66
# 1                               IT Services        57
# 2              Computer Hardware & Software        55
# 3                       Aerospace & Defense        45
# 4   Enterprise Software & Network Solutions        39
# 5                                Consulting        38
# 6                    Staffing & Outsourcing        35
# 7                        Insurance Carriers        28
# 8                                  Internet        23
# 9                   Advertising & Marketing        23
# 10         Health Care Services & Hospitals        21
# 11                   Research & Development        17
# 12                         Federal Agencies        16
# 13    Investment Banking & Asset Management        12
# 14                                  Lending         8

# %%
# Create circle bar for job posting count for each industry
# https://www.python-graph-gallery.com/circular-barplot-basic

plt.figure(figsize=(12,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 66
lowerLimit = 8
labelPadding = 4

# Compute max and min in the dataset
max = inds.Postings.max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * inds.Postings + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(inds.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(inds.index)+1))
angles = [element * width for element in indexes][::-1]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#33FF82",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, inds["Industry"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 
plt.title('Data Science Job Postings by Industry')
plt.savefig('images/industries.svg')

# %%
# count of desired skill
skillscount = pd.DataFrame(df2.sum(axis=0)[7:])
sc = skillscount.reset_index()
sc.columns=['Skill', 'Postings']
sc = sc.sort_values('Postings', ascending=False)
sc
# Out:
#       Skill Postings
# 0    python      424
# 1     excel      260
# 3     spark      161
# 4       aws      144
# 2    hadoop      125
# 6  big_data      123
# 5   tableau      112

# %%
# Create bar chart for skills
# https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/

all_colors = list(plt.cm.colors.cnames.keys())
random.seed(100)
c = random.choices(all_colors, k=7)

# Plot Bars
plt.figure(figsize=(10,6), dpi= 80)
plt.bar(sc.Skill, sc.Postings, color=c, width=.5)
for i, val in enumerate(sc.Postings.values):
    plt.text(i, val, float(val), horizontalalignment='center', verticalalignment='bottom', fontdict={'fontweight':400, 'size':12})

ticksrenamed = ['Python', 'Excel', 'Hadoop', 'Spark', 'AWS', 'Tableau', 'Big Data']

# Decoration
plt.gca().set_xticklabels(ticksrenamed, rotation=60, horizontalalignment= 'right', fontsize=12)
plt.title("Desirable Skills", fontsize=18)
plt.ylabel('Number of Postings', fontsize=15)
plt.xlabel('Skill', fontsize=15)
plt.ylim(0, 475)
plt.tight_layout()
plt.savefig('images/skills.svg')

# %%
df2.groupby('job_state').avg_salary.mean()
# Out:
# job_state
#  AL    142.000000
#  AZ    140.750000
#  CA    119.383459
#  CO    103.400000
#  CT     98.000000
#  DC    149.000000
#  DE    271.000000
#  FL    118.250000
#  GA    109.444444
#  IA    140.666667
#  IL    120.428571
#  IN    113.200000
#  KS    103.000000
#  LA    103.000000
#  MA    118.796610
#  MD    112.150000
#  MI    118.800000
#  MN     93.750000
#  MO    114.750000
#  MS    133.000000
#  NC    149.888889
#  NE    104.500000
#  NH    132.000000
#  NJ    121.571429
#  NY    133.543478
#  OH    118.636364
#  OK    122.500000
#  OR    131.500000
#  PA    115.800000
#  RI    130.500000
#  SC     95.500000
#  TN    101.875000
#  TX    127.500000
#  UT    104.333333
#  VA    127.936709
#  WA    134.466667
#  WI    144.333333
#  WV    114.000000
# Name: avg_salary, dtype: float64

# %%
# check average salary of California to make sure the math code below checks out.
df2[df2['job_state'].str.contains('CA')]['avg_salary'].mean()
# Out:
# 119.38345864661655

# %%
# get average salary of each state
# This is according to Glassdoor, not sure how trustworthy the numbers are
avgsalary = pd.DataFrame(df2.groupby('job_state').avg_salary.mean().astype(int))
avgsalary = avgsalary.sort_values('avg_salary', ascending=False)
avgsalary.reset_index()
# Out:
#    job_state  avg_salary
# 0         DE         271
# 1         DC         149
# 2         NC         149
# 3         WI         144
# 4         AL         142
# 5         IA         140
# 6         AZ         140
# 7         WA         134
# 8         NY         133
# 9         MS         133
# 10        NH         132
# 11        OR         131
# 12        RI         130
# 13        VA         127
# 14        TX         127
# 15        OK         122
# 16        NJ         121
# 17        IL         120
# 18        CA         119
# 19        OH         118
# 20        MA         118
# 21        MI         118
# 22        FL         118
# 23        PA         115
# 24        WV         114
# 25        MO         114
# 26        IN         113
# 27        MD         112
# 28        GA         109
# 29        NE         104
# 30        UT         104
# 31        LA         103
# 32        CO         103
# 33        KS         103
# 34        TN         101
# 35        CT          98
# 36        SC          95
# 37        MN          93

# %%
# dropped DE since it looked like an outlier
avgsalary1 = avgsalary[1:]
#avgsalary1 = avgsalary1.reset_index()
avgsalary1
# Out:
#    job_state  avg_salary
# 1         NC         149
# 2         WI         144
# 3         AL         142
# 4         IA         140
# 5         AZ         140
# 6         WA         134
# 7         NY         133
# 8         MS         133
# 9         NH         132
# 10        OR         131
# 11        RI         130
# 12        VA         127
# 13        TX         127
# 14        OK         122
# 15        NJ         121
# 16        IL         120
# 17        CA         119
# 18        OH         118
# 19        MA         118
# 20        MI         118
# 21        FL         118
# 22        PA         115
# 23        WV         114
# 24        MO         114
# 25        IN         113
# 26        MD         112
# 27        GA         109
# 28        NE         104
# 29        UT         104
# 30        LA         103
# 31        CO         103
# 32        KS         103
# 33        TN         101
# 34        CT          98
# 35        SC          95
# 36        MN          93

# %%
avgsalary1.to_csv('data/avgsalary.csv')

# %%
# https://www.python-graph-gallery.com/182-vertical-lollipop-plot

fig, ax = plt.subplots(1, figsize=(9,6))
# Reorder it based on the values
y_range=range(len(avgsalary1.job_state))[::-1]

ax.hlines(avgsalary1.job_state[::-1], xmin=0, xmax=avgsalary1['avg_salary'][::-1], color='skyblue')
ax.plot(avgsalary1['avg_salary'], y_range, "o")
 
ax.set_title("Average Salary by State")
ax.set_xlabel('Salary (USD in thousand)', fontsize=12)
ax.set_ylabel('State', fontsize=12)
ax.set_xlim(0,155)
plt.tight_layout()
plt.savefig('images/avgsalary.svg')

# not sure if we want to use this chart or use d3
